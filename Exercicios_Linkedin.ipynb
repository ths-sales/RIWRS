# %% [markdown]
# ### Linkedin - Empresas em que trabalham os meus contatos

# %%
CSV_FILE = '/Users/Thais Sales/Desktop/Pos/RIWRS/Basic_LinkedInDataExport_06-30-2018/Connections.csv'

# %%
from prettytable import PrettyTable
import sys
import nltk
import csv


# Handle any known abbreviations,
# strip off common suffixes, etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', '')]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i in range(len(companies)):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

ufu = 'Universidade Federal de Uberlândia'      
iftm = 'Instituto Federal de Educação, Ciência e Tecnologia do Triângulo Mineiro'
puc = 'Pontifícia Universidade Católica de Minas Gerais'
zup = 'Zup Innovation'
santander = 'Santander Brasil'
accenture = 'Accenture'
standardize = [('Federal University of Uberlandia', ufu), 
               ('UFU - Universidade Federal de Uberlândia', ufu), 
               ('Universidade Federal de Uberlândia - UFU', ufu), 
               ('IFTM - Inst. Fed. de Educação, Ciência e Tecnologia do Triângulo Mineiro', iftm),
               ('Federal University of Uberlândia',ufu),
               ('Universidade Federal de Uberlandia',ufu),
               ('Instituto Federal de Minas Gerais',iftm),
               ('Instituto Federal Minas Gerais',iftm),
               ('UFU',ufu),
               ('PUC Minas',puc),
               ('Zup It Innovation',zup),
               ('Zup - Connect & Transform',zup),
               ('Santander Brasil',santander),
               ('Accenture',accenture)
              ]
for i in range(len(companies)):
    for standard in standardize:
        companies[i] = companies[i].replace(standard[0],standard[1])

        
        
pt = PrettyTable(['Company', 'Freq'])

pt.align['Company'] = 'l'
fdist = nltk.FreqDist(companies)
[pt.add_row([company, freq]) for (company, freq) in fdist.items() if freq > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +---------------------------------------+------+
# | Company                               | Freq |
# +---------------------------------------+------+
# | Zup Innovation                        |  27  |
# | Cedro Technologies                    |  13  |
# | Algar Tech                            |  9   |
# | Softbox - Soluções Inteligentes em TI |  6   |
# | Neppo Tecnologia da Informação        |  5   |
# | Banco Triangulo S/A                   |  5   |
# | Autônomo                              |  5   |
# | Algar Telecom                         |  5   |
# | ValeCard                              |  4   |
# | Sankhya Gestão de Negócios            |  4   |
# | everis                                |  3   |
# | Callink Servicos de Call Center       |  3   |
# | Banco Santander                       |  3   |
# +---------------------------------------+------+

# %% [markdown]
# ### Linkedin - Cargos que ocupam os meus contatos

# %%
import sys
import nltk
import csv
from prettytable import PrettyTable

professor = 'Professor de Ensino Superior'
professor_basico = 'Professor'
analista_ti = 'Analista de Sistemas'
engenheiro_sw = 'Engenheiro de Software'
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ('Full Professor',professor),
    ('Professor Dedicação Exclusiva',professor),
    ('Professor Adjunto nível A',professor),
    ('Associate Professor',professor),
    ('Full Time Professor',professor),
    ('Professora Assistente',professor),
    ('Professor adjunto',professor),
    ('Professor do Magistério Superior',professor),
    ('Professora Adjunto',professor),
    ('Professora',professor),
    ('Adjunct Professor',professor),
    ('Professor de Ensino Superior',professor),
    ('Docente',professor_basico),
    #('Professor',professor_basico),
    ('Analista de TI',analista_ti),
    ('Systems Analyst',analista_ti),
    ('Analista de Sistemas, Especialista',analista_ti),
    ('Analista de TI - Administradora Siebel',analista_ti),
    ('Senior System Development Analyst C++',analista_ti),
    ('Analista Desenvolvedor de Sistemas',analista_ti),
    ('Analista de sistemas',analista_ti),
    ('Analista de Sistemas Especialista',analista_ti),
    ('System Analyst and Senior Full-Stack Developer',analista_ti),
    ('Analista de TI Pleno',analista_ti),
    ('Information Technology Analyst',analista_ti),
    ('Analista de sistema',analista_ti),
    ('Desenvolvedor e Analista de Sistemas',analista_ti),
    ('Analista Programador',analista_ti),
    ('Analista de Desenvolvimento de Sistemas',analista_ti),
    ('Analista de desenvolvimento de software',analista_ti),
    ('Analista de Tecnologia da Informação',analista_ti),
    ('System Analyst',analista_ti),
    ('Software Engineer',engenheiro_sw),
    ('Software Engineering',engenheiro_sw),
    ('System Software Engineer',engenheiro_sw),
    ('Software engineer',engenheiro_sw),
    ('Senior Software Engineer Team Lead',engenheiro_sw),
    ('Senior C++ Software Engineer',engenheiro_sw),
    ('Engenheiro de software',engenheiro_sw),
    ('Senior Engenheiro de Software',engenheiro_sw),
    ('System Engenheiro de Software',engenheiro_sw),
    ('Software Developer',engenheiro_sw),
    ('Desenvolvedor',engenheiro_sw),
    ('Analista Desenvolvedor',engenheiro_sw),
    ('Analista Engenheiro de Software',engenheiro_sw),
    ('Software Development Engineer',engenheiro_sw),
    ('Senior C++ Engenheiro de Software',engenheiro_sw),
    ('Engenheiro de Software na ZUP',engenheiro_sw),
    ('Staff Engenheiro de Software',engenheiro_sw)
    
    ]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO"
# Other variations could be handled as well such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i in range(len(titles)):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(['Position', 'Freq'])
pt.align['Position'] = 'l'
titles_fdist = nltk.FreqDist(titles)
[pt.add_row([title, freq]) for (title, freq) in titles_fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(['Token', 'Freq'])
pt.align['Token'] =  'l'
tokens_fdist = nltk.FreqDist(tokens)
[pt.add_row([token, freq]) for (token, freq) in tokens_fdist.items() if freq > 1
 and len(token) > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +------------------------------------+------+
# | Position                           | Freq |
# +------------------------------------+------+
# | Analista de Sistemas               |  12  |
# | Chief Executive Officer            |  7   |
# | Engenheiro de Software             |  5   |
# | Proprietário                       |  4   |
# | Diretor                            |  4   |
# | Analista de Recursos Humanos       |  4   |
# | Scrum Master                       |  3   |
# | Owner                              |  3   |
# | Gerente de projetos                |  3   |
# | Coordenador de TI                  |  3   |
# | QA                                 |  2   |
# | Professor                          |  2   |
# | Product Owner                      |  2   |
# | Headhunter                         |  2   |
# | Gerente de projetos de TI          |  2   |
# | Gerente comercial                  |  2   |
# | Engenheiro de Software de software |  2   |
# | Engenheiro de Software Front-End   |  2   |
# | Diretor Comercial                  |  2   |
# | Database Administrator             |  2   |
# | Coordenador                        |  2   |
# | Analista de testes                 |  2   |
# | Analista de RH                     |  2   |
# | Analista de Qualidade              |  2   |
# +------------------------------------+------+
# +-----------------+------+
# | Token           | Freq |
# +-----------------+------+
# | Analista        |  67  |
# | Gerente         |  36  |
# | Software        |  22  |
# | Engenheiro      |  20  |
# | Officer         |  17  |
# | Chief           |  17  |
# | Sistemas        |  13  |
# | Executive       |  13  |
# | Coordenador     |  13  |
# | Diretor         |  11  |
# | Senior          |  10  |
# | and             |  9   |
# | Projetos        |  8   |
# | Consultor       |  8   |
# | projetos        |  7   |
# | Manager         |  7   |
# | Humanos         |  7   |
# | Assistente      |  7   |
# | Analyst         |  7   |
# | Sales           |  6   |
# | Owner           |  6   |
# | Master          |  6   |
# | Developer       |  6   |
# | Comercial       |  6   |
# | Business        |  6   |
# | Suporte         |  5   |
# | Supervisor      |  5   |
# | Qualidade       |  5   |
# | Professor       |  5   |
# | Founder         |  5   |
# | Executivo       |  5   |
# | Especialista    |  5   |
# | testes          |  4   |
# | comercial       |  4   |
# | Vendas          |  4   |
# | Técnico         |  4   |
# | Scrum           |  4   |
# | Recursos        |  4   |
# | Proprietário    |  4   |
# | Processos       |  4   |
# | Marketing       |  4   |
# | Engineer        |  4   |
# | Director        |  4   |
# | sênior          |  3   |
# | suporte         |  3   |
# | software        |  3   |
# | negócios        |  3   |
# | financeiro      |  3   |
# | Talentos        |  3   |
# | Talent          |  3   |
# | Sênior          |  3   |
# | Socio           |  3   |
# | Quality         |  3   |
# | Product         |  3   |
# | Pleno           |  3   |
# | Planejamento    |  3   |
# | Negócios        |  3   |
# | Intelligence    |  3   |
# | Inovação        |  3   |
# | Governança      |  3   |
# | Gestor          |  3   |
# | Front-End       |  3   |
# | Financial       |  3   |
# | Estagiário      |  3   |
# | Designer        |  3   |
# | Data            |  3   |
# | Consultant      |  3   |
# | Co-Founder      |  3   |
# | Brazil          |  3   |
# | Auxiliar        |  3   |
# | Arquiteto       |  3   |
# | Architect       |  3   |
# | Agile           |  3   |
# | Administrador   |  3   |
# | rede            |  2   |
# | proprietário    |  2   |
# | operações       |  2   |
# | iOS             |  2   |
# | desenvolvimento |  2   |
# | desenvolvedor   |  2   |
# | administrativo  |  2   |
# | Web             |  2   |
# | Teste           |  2   |
# | Technology      |  2   |
# | Sócio           |  2   |
# | Solution        |  2   |
# | Requisitos      |  2   |
# | Representante   |  2   |
# | Project         |  2   |
# | Programador     |  2   |
# | PMO             |  2   |
# | Operações       |  2   |
# | Operating       |  2   |
# | Mobile          |  2   |
# | Manutenção      |  2   |
# | Líder           |  2   |
# | Java            |  2   |
# | Investimentos   |  2   |
# | Infraestrutura  |  2   |
# | IBM             |  2   |
# | Headhunter      |  2   |
# | Head            |  2   |
# | Geral           |  2   |
# | General         |  2   |
# | Fiscal          |  2   |
# | Financeiro      |  2   |
# | Farmacêutico    |  2   |
# | Eletricista     |  2   |
# | Diretora        |  2   |
# | Desenvolvimento |  2   |
# | Database        |  2   |
# | Big             |  2   |
# | Assurance       |  2   |
# | Administrator   |  2   |
# | Administrativo  |  2   |
# | Acquisition     |  2   |
# | Account         |  2   |
# +-----------------+------+

# %% [markdown]
# ### Linkedin - Clusterizando meus contatos por cargos

# %%
# -*- coding: utf-8 -*-

import sys
import csv
from nltk.metrics.distance import masi_distance
from nltk.metrics.distance import jaccard_distance


DISTANCE_THRESHOLD = 0.67
DISTANCE = jaccard_distance

#DISTANCE_THRESHOLD = 0.2
#DISTANCE = masi_distance


def cluster_contacts_by_title(csv_file):
   

    #separators = ['/', 'and', '&', 'de', '-', 'e', ' ']
    separators = ['/', 'and', '&', '-', 'de']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i in range(len(contacts)):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for title in titles:
            for seperator in separators:
                if title.find(seperator) >= 0:
                    if title in titles:
                        titles.remove(title)
                    titles.extend([title.strip() for title in title.split(seperator)
                                   if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            ##print(distance, set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)


    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]
    
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s.'
                                                              % (contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts


if __name__ == '__main__':
    clustered_contacts = cluster_contacts_by_title(CSV_FILE)

    for titles in clustered_contacts:
        common_titles_heading = 'Common Positions: ' + ', '.join(titles)
        
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
                                    + ', '.join(descriptive_terms)
        print(descriptive_terms_heading)
        print('-' * max(len(descriptive_terms_heading), len(common_titles_heading)))
        print('\n'.join(clustered_contacts[titles]))
        print()
# Out:
# Descriptive Terms: Engenheiro
# ----------------------------------------------------------
# Vinycius A.
# Luiz Felipe S.
# ()
# Descriptive Terms: r
# ------------------------------------------------------
# Miriam K.
# Miriam K.
# Gustavo T.
# Leonardo d.
# Leonardo d.
# Wesley P.
# Jony T.
# Lorena B.
# Antonio Pedro P.
# Filipe F.
# Thiago F.
# Thiago F.
# IT2YOU P.
# ()
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge M.
# Sergio S.
# Flavio S.
# Leandro S.
# Adalberto K.
# Delzilaine A.
# Johnatan C.
# Edgar Zattar D.
# Carlos M.
# Débora F.
# Renato M.
# Roberto F.
# Paulo Eustáquio C.
# Danilo M.
# Jimi S.
# Gabriel P.
# Robson Jose da S.
# Fabrício N.
# Fabricio M.
# Kriscia M.
# Thiago S.
# Caio C.
# Flávio V.
# Paulo Umberto (.
# Wanderson M.
# Thiago Campos M.
# Rodrigo B.
# Aurelio F.
# Douglas G.
# Joander S.
# Fidelidade V.
# Lilian S.
# Ayne D.
# Murillo N.
# Ivan Ricardo d.
# Olsenn R.
# ()
# Descriptive Terms: Senior, Analyst
# -----------------------------------------------------------------------------------------
# Weder C.
# Gabriela D.
# ()
# Descriptive Terms: Developer
# ---------------------------------------------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rodrigo S.
# Lorrayne P.
# Victor d.
# ()
# Descriptive Terms: em, Especialista
# ------------------------------------------------------------------------------------------------------------------------------
# Samuel P.
# Samir M.
# Diogo A.
# Ironides F.
# ()
# Descriptive Terms: negócios
# ------------------------------------------------
# Henrique F.
# Julio Anor E.
# Robson Jose da S.
# ()
# Descriptive Terms: senvolvedor
# -----------------------------------------------------
# Guilherme R.
# Madson S.
# ()
# Descriptive Terms: Qualida
# -----------------------------------------------
# Thiago R.
# Clayton M.
# Clayton M.
# Claudia E.
# ()
# Descriptive Terms:
# ------------------------------------------------
# Marco Túlio A.
# Jony T.
# Elder A.
# Caio C.
# IT2YOU P.
# ()
# Descriptive Terms: Developer
# ---------------------------------------------------------------------------------
# Rodrigo S.
# Rodrigo S.
# Frederico N.
# ()
# Descriptive Terms: Executive
# -------------------------------------------------
# Thiago B.
# David P.
# ()
# Descriptive Terms: Auxiliar
# ---------------------------------------------------
# Luana Kauara S.
# Douglas p.
# Fernando A.
# ()
# Descriptive Terms: Software
# ----------------------------------------------------
# Henrique L.
# Delzilaine A.
# Rafaiane M.
# Matheus G.
# ()
# Descriptive Terms: de, Analista
# ---------------------------------------------------------------------------------------------------------------
# Arthur D.
# Rafael S.
# Iara E.
# Cristiano R.
# ()
# Descriptive Terms:
# --------------------------------------------------------------------------------------------
# BRUNO Z.
# Alex S.
# Fábio C.
# Fabricio Ribeiro P.
# Gildean C.
# ()
# Descriptive Terms: em, Técnico
# --------------------------------------------------------------------
# João Alair C.
# Hallen P.
# ()
# Descriptive Terms: Suporte
# --------------------------------------------------------------------
# Lélio M.
# Leandro D.
# Rafael G.
# Eduardo F.
# ()
# Descriptive Terms: de, Engenheiro
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Carlos Alberto S.
# Rafael d.
# Alessandro R.
# Gustavo A.
# Flávio A.
# Alexandre B.
# Lucas G.
# ()
# Descriptive Terms: e
# -------------------------------------------------------------------------------------------------------------
# Eduardo F.
# Adriele C.
# Matheus O.
# ()
# Descriptive Terms: Comercial
# --------------------------------------------------------
# Fábio C.
# Gildean C.
# ()
# Descriptive Terms: Chief, Officer
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Guga S.
# Federico C.
# Ricardo R.
# Leonardo d.
# Edjay M.
# Geraldo F.
# Diego D.
# Thiago H.
# Rafael M.
# Marcilio O.
# Bruno P.
# João J.
# Thiago F.
# Fernando S.
# Fernando S.
# ()
# Descriptive Terms: Eletricista
# -----------------------------------------------------
# Sebastião V.
# Luiz Felipe S.
# ()
# Descriptive Terms: Assistente
# --------------------------------------------------------------------------------------------------
# Gilson S.
# Leandro D.
# Diego R.
# Gildean C.
# Walter M.
# Lorrane M.
# ()
# Descriptive Terms: Developer
# -----------------------------------------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rodrigo S.
# Lorrayne P.
# Frederico N.
# ()
# Descriptive Terms: Gerente
# -------------------------------------------------------------------------------------
# Jorge M.
# Sergio S.
# Flavio S.
# Adalberto K.
# Delzilaine A.
# Johnatan C.
# Edgar Zattar D.
# Débora F.
# Renato M.
# Roberto F.
# Danilo M.
# Jimi S.
# Gabriel P.
# Fabrício N.
# Fabricio M.
# Kriscia M.
# Thiago S.
# Caio C.
# Flávio V.
# Wanderson M.
# Thiago Campos M.
# Rodrigo B.
# Aurelio F.
# Douglas G.
# Joander S.
# Ayne D.
# Murillo N.
# Ivan Ricardo d.
# ()
# Descriptive Terms:
# ---------------------------------------------------------------
# Débora F.
# Roberto F.
# Paulo Eustáquio C.
# Lorena B.
# Fabricio M.
# Flávio V.
# Thiago Campos M.
# Ayne D.
# ()
# Descriptive Terms: Analyst
# --------------------------------------------------------
# Thiago S.
# Ana Luíza B.
# ()
# Descriptive Terms: sistemas
# ----------------------------------------------------
# Juvenil J.
# Samir M.
# Lucas V.
# ()
# Descriptive Terms: Gestor
# ------------------------------------------
# Fábio C.
# Murilo Roberto R.
# ()
# Descriptive Terms: Marketing
# ---------------------------------------------------------------------------------
# Patrick B.
# Romullo C.
# Gee M.
# Alexandre L.
# ()
# Descriptive Terms: de, Analista
# -------------------------------------------------------------------------------------------
# Arthur D.
# Rafael S.
# Cristiano R.
# ()
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------
# Jorge M.
# Sergio S.
# Flavio S.
# Adalberto K.
# Delzilaine A.
# Johnatan C.
# Edgar Zattar D.
# Débora F.
# Renato M.
# Roberto F.
# Danilo M.
# Jimi S.
# Gabriel P.
# Fabrício N.
# Fabricio M.
# Kriscia M.
# Thiago S.
# Caio C.
# Flávio V.
# Wanderson M.
# Thiago Campos M.
# Rodrigo B.
# Aurelio F.
# Aurelio F.
# Douglas G.
# Joander S.
# Fidelidade V.
# Lilian S.
# Ayne D.
# Murillo N.
# Ivan Ricardo d.
# ()
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------
# Marco Túlio A.
# Lucas R.
# Jony T.
# Elder A.
# Caio C.
# Paulo Umberto (.
# Hudson B.
# Cassio L.
# ()
# Descriptive Terms:
# --------------------------------------------------------------------
# Lucas R.
# Fabrício N.
# Hudson B.
# ()
# Descriptive Terms: Director
# ---------------------------------------------------------------------
# Hernan S.
# Gabriel H.
# Jone V.
# ()
# Descriptive Terms: Talentos, Humanos
# ----------------------------------------------------------
# Marayza F.
# Kriscia M.
# ()
# Descriptive Terms: suporte
# -------------------------------------------
# Diego R.
# Sergio S.
# ()
# Descriptive Terms: Chief, Officer
# ---------------------------------------------------------------------
# Diego D.
# Fernando S.
# Fernando S.
# ()
# Descriptive Terms: Supervisor
# ----------------------------------------------------
# Guilherme L.
# Isabela Cristine C.
# Rodrigo A.
# ()
# Descriptive Terms: Owner
# --------------------------------------
# Gaby Ester M.
# Assis M.
# Murilo N.
# Deborah B.
# Terry  H.
# ()
# Descriptive Terms: Planejamento, e
# ------------------------------------------------------------------------------
# José Guilherme B.
# Adriele C.
# ()
# Descriptive Terms: Chief
# ------------------------------------------------
# Daniel B.
# Daniel B.
# Fernando S.
# Fernando S.
# ()
# Descriptive Terms: Quality, Assurance
# ----------------------------------------------------------------------
# Rodrigo B.
# Fábio L.
# ()
# Descriptive Terms: de, Engenheiro, Software
# --------------------------------------------------------------------------
# Alessandro R.
# Lucas G.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------
# Robson X.
# Helio S.
# BRUNO Z.
# Alex S.
# Fabricio Ribeiro P.
# Carlos �.
# Estelita M.
# Diogo A.
# Vinicius M.
# Guilherme S.
# Vicente N.
# ()
# Descriptive Terms:
# ----------------------------------------------------------------------------------------
# Alexandre D.
# Danilo O.
# Danilo O.
# Gustavo B.
# Leandro Cassilha K.
# Guilherme G.
# ()
# Descriptive Terms: Co
# ---------------------------------
# José Henrique B.
# Marcelo S.
# Filipe F.
# Thiago F.
# Thiago F.
# ()
# Descriptive Terms: Analyst
# -----------------------------------------------------------------------------------------------------------------
# Weder C.
# Gabriel P.
# Thiago S.
# Ana Luíza B.
# ()
# Descriptive Terms: Gerente
# -------------------------------------------------------------
# Danilo M.
# Ivan Ricardo d.
# ()
# Descriptive Terms: Software
# ----------------------------------------------------
# Delzilaine A.
# Rafaiane M.
# Matheus G.
# Debliane d.
# ()
# Descriptive Terms: Supervisor
# --------------------------------------------------------------------------
# Isabela Cristine C.
# Rodrigo A.
# Gustavo C.
# Marília Carolina L.
# ()
# Descriptive Terms: testes
# --------------------------------------------
# Wesley P.
# Claudia Calegari R.
# Carlos Alberto Jr  , M.
# Iara E.
# ()
# Descriptive Terms: Consultor
# -------------------------------------------------------------------------------------------------
# Leandro S.
# Carlos M.
# Paulo Eustáquio C.
# Olsenn R.
# ()
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------
# Flavio S.
# Clesio B.
# Edgar Zattar D.
# ()
# Descriptive Terms: Processos
# ------------------------------------------------
# Marco M.
# Ricardo C.
# ()
# Descriptive Terms: comercial
# --------------------------------------------------------------------------------------
# Paulo C.
# Aurelio F.
# Fidelidade V.
# Lilian S.
# ()
# Descriptive Terms: Socio
# -----------------------------------------------
# Hernan S.
# Francisco T.
# ()
# Descriptive Terms: Diretora
# -----------------------------------------------------
# Solange F.
# Thais C.
# ()
# Descriptive Terms: Executivo
# --------------------------------------------------------
# Julio Anor E.
# José Augusto F.
# Antonio Carlos T.
# ()
# Descriptive Terms:
# -----------------------------------------------------------------------------------------
# Leandro A.
# Diego C.
# Clesio B.
# Paulo Henrique Q.
# Anderson R.
# Vanderlei G.
# Suzana F.
# Marayza F.
# Bruno R.
# Péricles Ferreira  .
# Mariana D.
# Tarcísio B.
# Kriscia M.
# Raphael M.
# ()
# Descriptive Terms: Consultor
# ----------------------------------------------------------------------------
# Carlos M.
# Paulo Eustáquio C.
# Olsenn R.
# ()
# Descriptive Terms: Gerente
# ---------------------------------------------------------------------------------------------------------------------------------------
# Jorge M.
# Sergio S.
# Flavio S.
# Adalberto K.
# Delzilaine A.
# Johnatan C.
# Edgar Zattar D.
# Débora F.
# Elder A.
# Renato M.
# Roberto F.
# Danilo M.
# Jimi S.
# Gabriel P.
# Fabrício N.
# MARCELO C.
# Fabricio M.
# Kriscia M.
# Thiago S.
# Caio C.
# Flávio V.
# Wanderson M.
# Thiago Campos M.
# Rodrigo B.
# Aurelio F.
# Douglas G.
# Matheus O.
# Ayne D.
# Murillo N.
# Ivan Ricardo d.
# ()
# Descriptive Terms: TI
# ------------------------------------------
# Diego C.
# Clesio B.
# Paulo Henrique Q.
# Edgar Zattar D.
# Jony T.
# Roberto F.
# Edimar A.
# Renato L.
# Diego R.
# Tarcísio B.
# Thiago S.
# Isabela Cristine C.
# Thiago Campos M.
# Paulo Ricardo C.
# Jucinei F.
# Juliano C.
# ()
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rafael F.
# Guilherme D.
# Delzilaine A.
# Carlos Alberto S.
# Leonardo Batista d.
# Eliezer S.
# Paulo Roberto P.
# Rodrigo F.
# Artur C.
# Rafaiane M.
# Rafael d.
# Alessandro R.
# Gustavo A.
# Flávio A.
# Matheus G.
# Matheus G.
# Alexandre B.
# Lucas G.
# Fábio P.
# Willian F.
# ()
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marco Túlio A.
# Flavio S.
# Diego C.
# Clesio B.
# Paulo Henrique Q.
# Edgar Zattar D.
# Jony T.
# Roberto F.
# Edimar A.
# Renato L.
# Samuel P.
# Diego R.
# Tarcísio B.
# Samir M.
# Thiago S.
# Isabela Cristine C.
# Diogo A.
# Thiago Campos M.
# Paulo Ricardo C.
# Jucinei F.
# Juliano C.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------------------------
# Rondinele S.
# Marco M.
# Ricardo C.
# Cassio L.
# ()
# Descriptive Terms: Assistente
# -----------------------------------------------------------------
# Gildean C.
# Lorrane M.
# ()
# Descriptive Terms: Assistente
# ----------------------------------------------------------
# Gilson S.
# Diego R.
# Raphael V.
# Walter M.
# ()
# Descriptive Terms: Farmacêutico
# -------------------------------------------------------
# Danilo M.
# Jeniffer L.
# ()
# Descriptive Terms: Manager
# ---------------------------------------------------------------------------
# Rui Pedro S.
# Wesley D.
# Leonardo R.
# ()
# Descriptive Terms: em, Especialista
# -----------------------------------------------------------------------
# Samir M.
# Diogo A.
# ()
# Descriptive Terms: Tra
# -------------------------------------
# Gustavo T.
# Gustavo C.
# ()
# Descriptive Terms: Analista
# ----------------------------------------------------------------------------------------------------------------------
# Taís F.
# Paulo L.
# José Guilherme B.
# Carine S.
# Henrique F.
# Luís Fernando S.
# Claudia Calegari R.
# Pedro Henrique F.
# Hugo P.
# Guilherme R.
# Thiago R.
# Paulo Roberto P.
# Estelita M.
# Isabel L.
# Lélio M.
# Madson S.
# Edimar A.
# Renato L.
# Vagner A.
# Erick Nascimento S.
# Andreia V.
# Clayton M.
# Clayton M.
# Marayza F.
# Daniel B.
# Odair D.
# Juvenil J.
# Rondinele S.
# Eliabe de Paula S.
# Rafaiane M.
# Rodolpho de Souza P.
# Isaac R.
# Anderson S.
# Letícia G.
# Carlos Alberto Jr  , M.
# Rafael V.
# Kassia F.
# LETICIA V.
# Evangelos M.
# Claudia E.
# Rafael G.
# Alexandre G.
# Cristiano G.
# Raphael V.
# Lorena C.
# Eduardo F.
# Lucas V.
# Marco M.
# Victor C.
# Fábio A.
# Hudson B.
# Tiago S.
# Fernanda Z.
# Paulo Ricardo C.
# Jose M.
# THAMARA D.
# Marilia M.
# Jucinei F.
# Letícia R.
# Cassio L.
# Sergio S.
# Joao P.
# ()
# Descriptive Terms: Chief
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Luis Fernando L.
# Daniel B.
# Daniel B.
# Geraldo F.
# Diego D.
# Fernando S.
# Fernando S.
# ()
# Descriptive Terms: Analista
# ----------------------------------------------------------------------
# Paulo Roberto P.
# Estelita M.
# Jose M.
# ()
# Descriptive Terms: Foun
# ------------------------------------
# Leonardo d.
# Leonardo d.
# Antonio Pedro P.
# Filipe F.
# Thiago F.
# Thiago F.
# IT2YOU P.
# ()
# Descriptive Terms: de, Engenheiro, Software
# --------------------------------------------------------------------------------------------------------
# Rafael d.
# Alessandro R.
# Gustavo A.
# Flávio A.
# Lucas G.
# ()
# Descriptive Terms: Vendas
# ----------------------------------------
# Renato M.
# Murilo Roberto R.
# Antonia  P.
# Olsenn R.
# ()
# Descriptive Terms: Comercial, Diretor
# ------------------------------------------------------------------
# BRUNO Z.
# Fabricio Ribeiro P.
# Romullo C.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------
# Robson X.
# BRUNO Z.
# Alex S.
# Fabricio Ribeiro P.
# Julio Anor E.
# José Augusto F.
# Olsenn R.
# ()
# Descriptive Terms: Diretor
# --------------------------------------------------------------------------------
# Robson X.
# Helio S.
# BRUNO Z.
# Alex S.
# Fabricio Ribeiro P.
# Carlos �.
# Diogo A.
# Vinicius M.
# Vicente N.
# ()
# Descriptive Terms: Humanos
# ----------------------------------------------------
# Isabel L.
# Andreia V.
# Rodolpho de Souza P.
# Kriscia M.
# Lorena C.
# ()
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------
# Carlos M.
# Leandro D.
# Gildean C.
# Lorrane M.
# ()
# Descriptive Terms: Projetos
# --------------------------------------------------------
# Marco Túlio A.
# Jony T.
# Elder A.
# Caio C.
# Cassio L.
# ()
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------
# Paulo Roberto P.
# Estelita M.
# Eliabe de Paula S.
# Eliabe de Paula S.
# Jose M.
# ()
# Descriptive Terms:
# -------------------------------------------------------------
# Wesley D.
# David P.
# Lucas R.
# ()
# Descriptive Terms: Teste
# --------------------------------------
# Hugo P.
# Rafaiane M.
# ()
# Descriptive Terms: Business
# --------------------------------------------------------------------------------------------
# Patrick B.
# Adriana Z.
# Alinson C.
# Tiago S.
# ()
# Descriptive Terms:
# --------------------------------------------------------
# Danilo O.
# Gustavo B.
# Antonio C.   C.
# ()
# Descriptive Terms: Analista
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Taís F.
# Paulo L.
# José Guilherme B.
# Carine S.
# Henrique F.
# Luís Fernando S.
# Claudia Calegari R.
# Pedro Henrique F.
# Hugo P.
# Guilherme R.
# Viviane B.
# Thiago R.
# Paulo Roberto P.
# Estelita M.
# Isabel L.
# Lélio M.
# Madson S.
# Edimar A.
# Renato L.
# Erick Nascimento S.
# Andreia V.
# Clayton M.
# Clayton M.
# Marayza F.
# Daniel B.
# Odair D.
# Juvenil J.
# Rondinele S.
# Eliabe de Paula S.
# Rafael S.
# Rafaiane M.
# Rodolpho de Souza P.
# Isaac R.
# Anderson S.
# Letícia G.
# Carlos Alberto Jr  , M.
# Rafael V.
# Kassia F.
# LETICIA V.
# Evangelos M.
# Claudia E.
# Rafael G.
# Alexandre G.
# Cristiano G.
# Raphael V.
# Lorena C.
# Eduardo F.
# Lucas V.
# Marco M.
# Victor C.
# Fábio A.
# Hudson B.
# Tiago S.
# Fernanda Z.
# Iara E.
# Paulo Ricardo C.
# Jose M.
# THAMARA D.
# Marilia M.
# Jucinei F.
# Letícia R.
# Cassio L.
# Sergio S.
# Joao P.
# Cristiano R.
# ()
# Descriptive Terms: Sales
# ----------------------------------------
# Adriana Z.
# Gabriela D.
# ()
# Descriptive Terms: Suporte
# -----------------------------------------------------
# Leandro D.
# Rafael G.
# Raphael V.
# Eduardo F.
# ()
# Descriptive Terms:
# ---------------------------------------------------------
# Marcos L.
# Wesley D.
# Adriana Z.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------
# Luís Fernando S.
# Pedro Henrique F.
# Rafael S.
# Rafael V.
# Joao P.
# Cristiano R.
# ()
# Descriptive Terms: r
# ---------------------------------------------------
# Gustavo T.
# Jony T.
# IT2YOU P.
# ()
# Descriptive Terms: Investimentos
# -----------------------------------------------------
# Thalita Kauara S.
# Gabriel P.
# ()
# Descriptive Terms: Especialista
# --------------------------------------------------------
# Marco Túlio A.
# Samir M.
# ()
# Descriptive Terms: Director
# -----------------------------------------------
# Gabriel H.
# Bruno N.
# ()
# Descriptive Terms: de, Engenheiro, Software
# ------------------------------------------------------------------------------------------------------------------------------------
# Carlos Alberto S.
# Rafael d.
# Alessandro R.
# Gustavo A.
# Flávio A.
# Lucas G.
# ()
# Descriptive Terms: Designer
# ----------------------------------------------------------------------
# Roberta Caetano F.
# Tiago M.
# Deborah B.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------
# Paulo L.
# Paulo Eustáquio C.
# Diego R.
# Fabricio M.
# Sergio S.
# ()
# Descriptive Terms:
# ---------------------------------------------------------------------------
# Delzilaine A.
# Anderson S.
# Claudia E.
# ()
# Descriptive Terms: Sistemas
# --------------------------------------------------
# Luís Fernando S.
# Pedro Henrique F.
# Leonardo Batista d.
# Rafael V.
# Joao P.
# ()
# Descriptive Terms: Chief
# -------------------------------------------------------------------------------------------------------------------------------
# Guga S.
# Daniel B.
# Daniel B.
# Federico C.
# Ricardo R.
# Leonardo d.
# Edjay M.
# Geraldo F.
# Diego D.
# Rafael M.
# Marcilio O.
# Bruno P.
# João J.
# Thiago F.
# Fernando S.
# Fernando S.
# ()
# Descriptive Terms: Consultor
# -----------------------------------------------------------------------------------------------------------------------------------------
# Leandro S.
# Carlos M.
# Paulo Eustáquio C.
# Robson Jose da S.
# Antonio Carlos T.
# Olsenn R.
# ()
# Descriptive Terms: de, Engenheiro
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rafael F.
# Guilherme D.
# Carlos Alberto S.
# Leonardo Batista d.
# Eliezer S.
# Paulo Roberto P.
# Rodrigo F.
# Artur C.
# Rafael d.
# Alessandro R.
# Gustavo A.
# Flávio A.
# Matheus G.
# Alexandre B.
# Lucas G.
# Mário Sérgio E.
# Fábio P.
# Willian F.
# ()
# Descriptive Terms: Analista
# -------------------------------------------------
# Paulo Roberto P.
# Jose M.
# ()
# Descriptive Terms: Socio
# ------------------------------------------------------
# Hernan S.
# Euripedes S.
# Francisco T.
# ()
# Descriptive Terms: Manager
# -------------------------------------------------------------------------
# Rui Pedro S.
# Renato V.
# Wesley D.
# ()
# Descriptive Terms: Planejamento, e
# -------------------------------------------------------------------------------
# José Guilherme B.
# Pablo R.
# ()
# Descriptive Terms: end
# --------------------------------
# Gustavo A.
# Lucas G.
# ()
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------
# Carlos M.
# Julio Anor E.
# José Augusto F.
# Antonio Carlos T.
# Olsenn R.
# ()
# Descriptive Terms:
# --------------------------------------------------------------------------
# Danilo O.
# Gustavo B.
# Leandro Cassilha K.
# Guilherme G.
# ()

# %% [markdown]
# ### Linkedin - Visualizando o agrupamento dos meus contatos por cargo

# %%
import os
import sys
import json
import webbrowser


HTML_TEMPLATE = 'dojo-tree.html'

data = {"label": "name", "temp_items": {}, "items": []}

clustered_contacts = cluster_contacts_by_title(CSV_FILE)

for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if descriptive_terms in data['temp_items']:
        data['temp_items'][descriptive_terms].extend([{'name': cc} for cc
                                                      in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name': cc} for cc
                                                 in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name": "%s (%s)" % (descriptive_terms,
                                               len(data['temp_items'][descriptive_terms]),),
                          "children": [i for i in
                                       data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

if not os.path.isdir('out'):
    os.mkdir('out')

OUT = os.path.join('out', 'dojo-tree.html')

t = open(HTML_TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

webbrowser.open("file://" + os.path.join(os.getcwd(), OUT))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-3c08631e45c4> in <module>()
#      41 t = open(HTML_TEMPLATE).read()
#      42 f = open(OUT, 'w')
# ---> 43 f.write(t % json.dumps(data, indent=4))
#      44 f.close()
#      45
#
# c:\python27\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     249         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     250         separators=separators, encoding=encoding, default=default,
# --> 251         sort_keys=sort_keys, **kw).encode(obj)
#     252
#     253
#
# c:\python27\lib\json\encoder.pyc in encode(self, o)
#     207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
# --> 209             chunks = list(chunks)
#     210         return ''.join(chunks)
#     211
#
# c:\python27\lib\json\encoder.pyc in _iterencode(o, _current_indent_level)
#     432                 yield chunk
#     433         elif isinstance(o, dict):
# --> 434             for chunk in _iterencode_dict(o, _current_indent_level):
#     435                 yield chunk
#     436         else:
#
# c:\python27\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# c:\python27\lib\json\encoder.pyc in _iterencode_list(lst, _current_indent_level)
#     330                 else:
#     331                     chunks = _iterencode(value, _current_indent_level)
# --> 332                 for chunk in chunks:
#     333                     yield chunk
#     334         if newline_indent is not None:
#
# c:\python27\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# c:\python27\lib\json\encoder.pyc in _iterencode_list(lst, _current_indent_level)
#     330                 else:
#     331                     chunks = _iterencode(value, _current_indent_level)
# --> 332                 for chunk in chunks:
#     333                     yield chunk
#     334         if newline_indent is not None:
#
# c:\python27\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     388             yield _key_separator
#     389             if isinstance(value, basestring):
# --> 390                 yield _encoder(value)
#     391             elif value is None:
#     392                 yield 'null'
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xc3 in position 7: invalid continuation byte
